# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)  

train = pd.read_csv('./dataset/train.csv')

train.head(1)
#train['MSSubClass']
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ         706          Unf           0        150          856
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# ...

# %%
sns.kdeplot(train.SalePrice)

# %%
#train['MSSubClass'].value_counts()
sns.barplot(x='MSSubClass', y='SalePrice', data=train)

# %%
sns.barplot(x='MSZoning', y='SalePrice', data=train)
#train[train['MSZoning'] == 'RL']['SalePrice'].value_counts()

# %%
train['LotFrontage'].plot.hist()
sns.jointplot(x='LotFrontage', y='SalePrice', data=train[train['LotFrontage'] < 160],  kind='hex')

# %% [markdown]
# LotFrontage is the linear feet of street connected to property
# Compare to the price, we can see a corelation between LotFrontage and SalePrice.

# %%
train['LotArea'].value_counts()
sns.jointplot(x='LotArea', y='SalePrice', data=train[train['LotArea'] < 40000], kind='hex')

# %% [markdown]
# Lot is the size in square feet
# The house between 5000 and 15000 square feet are comprise between 100000 and 2000000 $

# %%
train['Street'].value_counts().plot.bar()
sns.barplot(x='Street', y='SalePrice', data=train)

# %% [markdown]
# Street is the type of road access to property
# This variable won't help us because the error rate is too high for Grvl AND houses inside town are generaly with Paved thus have SalePrice higher than Gravel.

# %%
#train[train['Alley'] == 'NA'].value_counts()

sns.barplot(x='Alley', y='SalePrice', data=train)

# %% [raw]
# Alley is the type of alley access to property
# Alley with Paved have higher price than alley with Gravel.
# Sign of richess ?

# %%
sns.barplot(x='LotShape', y='SalePrice', data=train)

# %%
ax = sns.barplot(x='LandContour', y='SalePrice', data=train)
plt.show()

sns.barplot(x='LandContour', y='LotArea', data=train)

# %% [markdown]
# LandContour is the flatness of the property
# HLS for Hillside - Significant slope from side to side
# Lvl means near Flat/Level
# We can see HLS and LOW have higher price. Due to the dificulty to build ? More materials to build ?
#
# *HLS are the most expensive but they have the less size in square feet (LotArea)*

# %%
condSalePrice = train['SalePrice'] < train['SalePrice'].median()
utilities = train['Utilities'] == 'AllPub'
train[utilities & condSalePrice][1:10]
#train['SalePrice'].median()
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 5    6          50       RL         85.0    14115   Pave   NaN      IR1
# 8    9          50       RM         51.0     6120   Pave   NaN      Reg
# 9   10         190       RL         50.0     7420   Pave   NaN      Reg
# 10  11          20       RL         70.0    11200   Pave   NaN      Reg
# 12  13          20       RL          NaN    12968   Pave   NaN      IR2
# 14  15          20       RL          NaN    10920   Pave   NaN      IR1
# 15  16          45       RM         51.0     6120   Pave   NaN      Reg
# 16  17          20       RL          NaN    11241   Pave   NaN      IR1
# 17  18          90       RL         72.0    10791   Pave   NaN      Reg
#
#    LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 5          Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 8          Lvl    AllPub    Inside       Gtl      OldTown     Artery
# ...

# %% [markdown]
# Utilities are All public Utilities (E,G,W,& S) or Electricity, Gas, and Water (Septic Tank) or Electricity and Gas Only exemples.
# There is no corelation between SalePrice and Utilities.
# The only house which is not AllPub are not below the median price.
